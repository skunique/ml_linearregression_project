# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('hours_scores.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.scatter(df.Hours,df['Scores'],marker='+',color='red')
plt.show()

# %% [markdown]
# reg = linear_model.LinearRegression()
# reg.fit(df['Hours'],df['Scores'])

# %%
X = df[['Hours']]
y = df[['Scores']]

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict([[1]])
# Out:
# C:\Users\91887\skunique\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[11.92881652]])

# %% [raw]
# r2_score = reg.score(X_train, y_train)
# print(f"R^2 Score: {r2_score}")
